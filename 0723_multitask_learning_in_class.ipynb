# %% [markdown]
# # 삼성 DS-KAIST AI Expert 프로그램
# ## Week 4: Multitask Learning
#
# 실습 일시: 2019년 7월 23일 (화), 13:30 - 17:30
#
# 담당 조교: 이한국 (hankook.lee@kaist.ac.kr)
#
# # Section 0. Introduction
#
# 본 실습에서는 TensorFlow와 Keras 프레임워크를 이용하여, multi-task learning에 관한 실습을 진행할 것입니다. multi-task learning은 여러가지 테스크를 동시에 학습함으로써 공통된 유용한 feature를 효과적으로 배우는 방법으로, 어떤 효과가 있는지 알아볼 예정입니다.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %% [markdown]
# ### Hyperparamters
#
# 아래는 이번 실습에서 사용할 hyperparameter들을 사전 정의해 둔 것입니다.

# %%
batch_size = 128
steps_per_epoch = 300
num_epochs = 10

# %% [markdown]
# # Section 1. Load Dataset (CIFAR-10, CIFAR-100)
#
# 이번 실습에서 사용할 dataset은 CIFAR-10과 CIFAR-100 입니다. 각 dataset은 총 50000개의 training image를 가지고 있고, 10000개의 test image를 가지고 있습니다. 또한, CIFAR-10의 이미지는 10개의 class중 하나에 속하고, CIFAR-100의 이미지는 100개의 class중 하나에 속하게 됩니다.

# %%
cifar10 = tf.keras.datasets.cifar10
cifar100 = tf.keras.datasets.cifar100

# %%
(x_train_c10, y_train_c10), (x_test_c10, y_test_c10) = cifar10.load_data()
(x_train_c100, y_train_c100), (x_test_c100, y_test_c100) = cifar100.load_data()

# %%
print('CIFAR-10 ------')
print('트레이닝 샘플 수: %d' % x_train_c10.shape[0])
print('이미지 크기: %d x %d x %d' % (x_train_c10.shape[1], x_train_c10.shape[2], x_train_c10.shape[3]))
print('트레이닝 데이터 크기: %d x %d x %d x %d' % (*x_train_c10.shape, ))
print('')
print('CIFAR-100 ------')
print('트레이닝 샘플 수: %d' % x_train_c100.shape[0])
print('이미지 크기: %d x %d x %d' % (x_train_c100.shape[1], x_train_c100.shape[2], x_train_c100.shape[3]))
print('트레이닝 데이터 크기: %d x %d x %d x %d' % (*x_train_c100.shape, ))
# Out:
# CIFAR-10 ------
# 트레이닝 샘플 수: 50000
# 이미지 크기: 32 x 32 x 3
# 트레이닝 데이터 크기: 50000 x 32 x 32 x 3
#
# CIFAR-100 ------
# 트레이닝 샘플 수: 50000
# 이미지 크기: 32 x 32 x 3
# 트레이닝 데이터 크기: 50000 x 32 x 32 x 3

# %% [markdown]
# ### Preprocessing Data
# Image의 pixel 의 값은 (R, G, B) 형태로 표현되고, 각 channel (R/G/B) 마다 [0, 1, 2, ..., 255] 의 정수 값을 가집니다. 일반적으로 neural network를 학습할 때에는 normalized 되어있는 값을 input으로 사용하는 것이 좋습니다. 따라서, 각 image 값들을 [0, 1/255, ..., 1.0] 의 실수 값으로 치환해줍니다.
# Image의 label 은 [0, 1, 2, ..., 9] 의 값을 가집니다. 이러한 label 정보는 일반적으로 one-hot encoding으로 바꿔주어 사용합니다. one-hot encoding을 하게 되면 label 0은 [1, 0, 0, ..., 0], label 1은 [0, 1, 0, ..., 0], 그리고 label 9는 [0, 0, 0, ..., 1]으로 바뀌게 됩니다.

# %%
x_train_c10 = x_train_c10 / 255.0
x_test_c10 = x_test_c10 / 255.0

y_train_c10 = tf.keras.utils.to_categorical(y_train_c10, 10)
y_test_c10 = tf.keras.utils.to_categorical(y_test_c10, 10)

# %%
x_train_c100 = x_train_c100 / 255.0
x_test_c100 = x_test_c100 / 255.0

y_train_c100 = tf.keras.utils.to_categorical(y_train_c100, 100)
y_test_c100 = tf.keras.utils.to_categorical(y_test_c100, 100)

# %% [markdown]
# ### Data Generator
#
# `ImageDataGenerator`는 Keras에 있는 API 중 하나로, data augmentation (좌우 반전 등) 을 손쉽게 할 수 있습니다. 가능한 data augmentation 방법들은 내용은 https://keras.io/preprocessing/image/ 에서 확인하실 수 있습니다. 이번 실습에서는 일반적으로 CIFAR dataset에서 사용하는 random 상하좌우 shift와 좌우 반전을 사용할 것입니다.

# %%
datagen_c10 = tf.keras.preprocessing.image.ImageDataGenerator(
    width_shift_range=5,
    height_shift_range=5,
    fill_mode='constant',
    horizontal_flip=True).flow(x_train_c10, y_train_c10, batch_size=batch_size)

# %%
datagen_c100 = tf.keras.preprocessing.image.ImageDataGenerator(
    width_shift_range=5,
    height_shift_range=5,
    fill_mode='constant',
    horizontal_flip=True).flow(x_train_c100, y_train_c100, batch_size=batch_size)

# %% [markdown]
# Test data를 위한 DataGenerator를 만들기 위해 아래의 함수를 선언하였습니다. Batch를 앞에서부터 100개씩 구성합니다.

# %%
def test_datagen(x, y):
    assert x.shape[0] == 10000
    assert y.shape[0] == 10000
    while True:
        for i in range(0, 10000, 100):
            yield x[i:i+100], y[i:i+100]

# %%
test_datagen_c10 = test_datagen(x_test_c10, y_test_c10)
test_datagen_c100 = test_datagen(x_test_c100, y_test_c100)

# %% [markdown]
# Multi-task learning을 위해서는, 2개의 data generator를 하나의 data generator로 합쳐줘야합니다. 아래의 함수를 통해 두개의 generator를 합칠 수 있습니다.

# %%
def merge_datagen(datagen1, datagen2):
    while True:
        x1, y1 = next(datagen1)
        x2, y2 = next(datagen2)
        yield [x1, x2], [y1, y2]

# %%
datagen = merge_datagen(datagen_c10, datagen_c100)
test_datagen = merge_datagen(test_datagen_c10, test_datagen_c100)

# %% [markdown]
# ### Plotting Images
#
# 아래의 script를 이용하여 각 데이터셋에 어떤 이미지들이 들어있는지 확인할 수 있습니다.

# %%
plt.figure(figsize=(6,6))
plt.suptitle('CIFAR-10 training images', fontsize=16)
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.imshow(x_train_c10[i])
    plt.axis('off')
    
plt.figure(figsize=(6,6))
plt.suptitle('CIFAR-100 training images', fontsize=16)
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.imshow(x_train_c100[i])
    plt.axis('off')

# %% [markdown]
# # Section 2. Multi-task Learning using Keras
#
# 이번 실습에서는 간단한 6-layer CNN을 사용할 것입니다. multi-task learning을 위해서, 2 종류의 inputs을 받고, 2 종류의 outputs을 출력하는 형태로 network를 design할 것입니다.

# %% [markdown]
# `build_shared_conv_block`은 convolutional layer와, batch normalization layer, 그리고 relu activation으로 구성된 하나의 convolutional block입니다.
# 두 개의 입력값 `inputs1`, `inputs2` 은 같은 layer를 공유해야하기 때문에, Keras API로 먼저 layer을 선언하고, 선언된 layer를 이용하여 출력값을 구해줍니다.

# %%
def build_shared_conv_block(inputs1, inputs2, num_channels):
    # define layers
    conv = Conv2D(num_channels, (3, 3), padding='same')
    bn = BatchNormalization()
    relu = Activation('relu')
    
    # compute outputs
    outputs1 = relu(bn(conv(inputs1)))
    outputs2 = relu(bn(conv(inputs2)))
    return outputs1, outputs2

# %% [markdown]
# `build_network`는 multi-task를 다룰 수 있는 하나의 CNN을 만드는 역할을 합니다. 이 함수는 `inputs1`, `inputs2`, `num_classes1`, `num_classes2`, `base_width` 다섯 개의 인자를 받습니다.
# - `inputs1`, `inputs2`: 각 task의 input을 의미합니다.
# - `num_classes1`, `num_classes2`: 각 task의 output dimension을 의미합니다. CIFAR-10, CIFAR-100을 사용할 것이므로, 10 / 100 이 됩니다.
# - `base_width`: network의 width를 나타내는 역할을 합니다. teacher model로 wide한 모델을 사용할 것이고, student 모델로는 thin한 모델을 사용할 예정입니다.
#
# `build_network`는 총 2개의 tensor를 return합니다.
# - `outputs1`, `outputs2`: network의 최종 출력값으로, 각 task에 대한 output을 의미합니다.

# %% [markdown]
# ## Q1. Build Separated Dense Layers (20 min)
#
# 아래의 코드에서 `x1, x2`는 layer를 공유하는 형태로 계산된 feature입니다. 여기서 `Dense` layer를 이용하되, 하나의 task 마다 하나의 `Dense` layer가 생기도록 구현해보세요.
# 각 `Dense` layer의 output dimension은 `num_classes1`과 `num_classes2`가 되어야 합니다. 비슷하게, Softmax activation도 구현하세요.
#
# Transfer learning 실습 코드를 참고하면 좋습니다.

# %%
def build_network(inputs1, inputs2, num_classes1=10, num_classes2=100, base_width=16):
    x1, x2 = build_shared_conv_block(inputs1, inputs2, base_width)
    x1, x2 = build_shared_conv_block(x1, x2, base_width)
    
    pool1 = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same')
    x1, x2 = pool1(x1), pool1(x2)
    x1, x2 = build_shared_conv_block(x1, x2, base_width*2)
    x1, x2 = build_shared_conv_block(x1, x2, base_width*2)

    pool2 = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same')
    x1, x2 = pool2(x1), pool2(x2)
    x1, x2 = build_shared_conv_block(x1, x2, base_width*4)
    x1, x2 = build_shared_conv_block(x1, x2, base_width*4)

    pool3 = GlobalAveragePooling2D()
    x1, x2 = pool3(x1), pool3(x2)
    
    '''
    logits = GlobalAveragePooling2D()(x3)
    logits = Dense(num_classes)(logits)
    outputs = Activation('softmax')(logits)
    '''
    
    # Q1. Separated Dense layers
    logits1 = Dense(num_classes1)(x1)
    logits2 = Dense(num_classes2)(x2)
    
    outputs1 = Activation('softmax', name='outputs1')(logits1)
    outputs2 = Activation('softmax', name='outputs2')(logits2)
    
    return outputs1, outputs2

# %%
inputs1 = Input(shape=(32, 32, 3), name='inputs1')
inputs2 = Input(shape=(32, 32, 3), name='inputs2')

# %% [markdown]
# ## Define Model
#
# 먼저, `base_width=16`인 network를 정의합니다. 이 모델은 inputs이 2개, outputs이 2개인 모델입니다.

# %%
outputs1, outputs2 = build_network(inputs1, inputs2, base_width=8)
model = tf.keras.models.Model(inputs=[inputs1, inputs2], outputs=[outputs1, outputs2], name='model')
model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0729 21:41:07.797605 15448 deprecation.py:506] From C:\Users\PC\Anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# inputs1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# inputs2 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 8)    224         inputs1[0][0]
#                                                                  inputs2[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 8)    32          conv2d[0][0]
#                                                                  conv2d[1][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 8)    0           batch_normalization[0][0]
#                                                                  batch_normalization[1][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 8)    584         activation[0][0]
#                                                                  activation[1][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 8)    32          conv2d_1[0][0]
#                                                                  conv2d_1[1][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 8)    0           batch_normalization_1[0][0]
#                                                                  batch_normalization_1[1][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 16, 16, 8)    0           activation_1[0][0]
#                                                                  activation_1[1][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 16, 16, 16)   1168        max_pooling2d[0][0]
#                                                                  max_pooling2d[1][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 16, 16, 16)   64          conv2d_2[0][0]
#                                                                  conv2d_2[1][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 16, 16, 16)   0           batch_normalization_2[0][0]
#                                                                  batch_normalization_2[1][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 16, 16, 16)   2320        activation_2[0][0]
#                                                                  activation_2[1][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 16)   64          conv2d_3[0][0]
#                                                                  conv2d_3[1][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 16, 16, 16)   0           batch_normalization_3[0][0]
#                                                                  batch_normalization_3[1][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 8, 8, 16)     0           activation_3[0][0]
#                                                                  activation_3[1][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 8, 8, 32)     4640        max_pooling2d_1[0][0]
#                                                                  max_pooling2d_1[1][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 8, 8, 32)     128         conv2d_4[0][0]
#                                                                  conv2d_4[1][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 8, 8, 32)     0           batch_normalization_4[0][0]
#                                                                  batch_normalization_4[1][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 8, 8, 32)     9248        activation_4[0][0]
#                                                                  activation_4[1][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 8, 8, 32)     128         conv2d_5[0][0]
#                                                                  conv2d_5[1][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 8, 8, 32)     0           batch_normalization_5[0][0]
#                                                                  batch_normalization_5[1][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 32)           0           activation_5[0][0]
#                                                                  activation_5[1][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           330         global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 100)          3300        global_average_pooling2d[1][0]
# __________________________________________________________________________________________________
# outputs1 (Activation)           (None, 10)           0           dense[0][0]
# __________________________________________________________________________________________________
# outputs2 (Activation)           (None, 100)          0           dense_1[0][0]
# ==================================================================================================
# Total params: 22,262
# Trainable params: 22,038
# Non-trainable params: 224
# __________________________________________________________________________________________________

# %% [markdown]
# 아래 함수 `plot_history`는 training curve를 시각화하는 함수입니다. 학습 후 성능이 어떻게 변화하는지 관측해볼 것입니다.

# %%
def plot_history(history):
    epochs = len(history.history['loss'])
    plt.figure(figsize=(20, 3))

    plt.subplot(1, 4, 1)
    plt.title('loss')
    plt.plot(range(epochs), history.history['outputs1_loss'], 'r')
    plt.plot(range(epochs), history.history['val_outputs1_loss'], 'b')
    plt.legend(['train', 'val'])

    plt.subplot(1, 4, 2)
    plt.title('accuracy')
    plt.plot(range(epochs), history.history['outputs1_acc'], 'r--')
    plt.plot(range(epochs), history.history['val_outputs1_acc'], 'b--')    
    plt.legend(['train', 'val'])

    plt.subplot(1, 4, 3)
    plt.title('loss')
    plt.plot(range(epochs), history.history['outputs2_loss'], 'r')
    plt.plot(range(epochs), history.history['val_outputs2_loss'], 'b')
    plt.legend(['train', 'val'])

    plt.subplot(1, 4, 4)
    plt.title('accuracy')
    plt.plot(range(epochs), history.history['outputs2_acc'], 'r--')
    plt.plot(range(epochs), history.history['val_outputs2_acc'], 'b--')    
    plt.legend(['train', 'val'])

    print('CIFAR10  최대 도달 성능: %.2f%%' % (max(history.history['val_outputs1_acc'])*100,))
    print('CIFAR100 최대 도달 성능: %.2f%%' % (max(history.history['val_outputs2_acc'])*100,))

# %% [markdown]
# ## Train Model on CIFAR-10 & CIFAR-100

# %% [markdown]
# 두 가지 데이터를 동시에 학습해야 하므로, 다음과 같이 compile해줍니다.

# %%
model.compile(optimizer='adam',
              loss=['categorical_crossentropy', 'categorical_crossentropy'], # output이 2개이기 때문에 각각에 대해 loss를 지정해주어야 합니다.
              metrics=['accuracy', 'accuracy']) # output이 2개이기 때문에 각각에 대해 metric을 지정해주어야 합니다.

# %% [markdown]
# 그리고 Model의 `fit_generator`를 사용하여 네트워크를 학습해줍니다. 여기서 `generator`는 위에서 선언한 data augmentation이 된 dataset으로 생각할 수 있습니다. `steps_per_epoch`은 한 epoch마다 iteration 수를, `epochs`는 총 epoch을 나타냅니다.

# %%
history = model.fit_generator(datagen,
                              steps_per_epoch=steps_per_epoch,
                              epochs=num_epochs,
                              validation_data=test_datagen,
                              validation_steps=100, verbose=1)
# Out:
# Epoch 1/10
# 300/300 [==============================] - 102s 341ms/step - loss: 6.0927 - outputs1_loss: 1.7515 - outputs2_loss: 4.3412 - outputs1_acc: 0.3657 - outputs2_acc: 0.0525 - val_loss: 5.6374 - val_outputs1_loss: 1.5848 - val_outputs2_loss: 4.0526 - val_outputs1_acc: 0.4121 - val_outputs2_acc: 0.0754
# Epoch 2/10
# 300/300 [==============================] - 99s 330ms/step - loss: 5.2611 - outputs1_loss: 1.4234 - outputs2_loss: 3.8377 - outputs1_acc: 0.4861 - outputs2_acc: 0.1140 - val_loss: 5.0866 - val_outputs1_loss: 1.4322 - val_outputs2_loss: 3.6544 - val_outputs1_acc: 0.4915 - val_outputs2_acc: 0.1270
# Epoch 3/10
# 300/300 [==============================] - 99s 329ms/step - loss: 4.8488 - outputs1_loss: 1.2948 - outputs2_loss: 3.5540 - outputs1_acc: 0.5335 - outputs2_acc: 0.1531 - val_loss: 4.8317 - val_outputs1_loss: 1.3461 - val_outputs2_loss: 3.4856 - val_outputs1_acc: 0.5199 - val_outputs2_acc: 0.1522
# Epoch 4/10
# 300/300 [==============================] - 99s 331ms/step - loss: 4.5902 - outputs1_loss: 1.2131 - outputs2_loss: 3.3772 - outputs1_acc: 0.5633 - outputs2_acc: 0.1787 - val_loss: 4.5299 - val_outputs1_loss: 1.1762 - val_outputs2_loss: 3.3536 - val_outputs1_acc: 0.5753 - val_outputs2_acc: 0.1745
# Epoch 5/10
# 300/300 [==============================] - 99s 330ms/step - loss: 4.4283 - outputs1_loss: 1.1635 - outputs2_loss: 3.2648 - outputs1_acc: 0.5800 - outputs2_acc: 0.1997 - val_loss: 4.4843 - val_outputs1_loss: 1.2633 - val_outputs2_loss: 3.2210 - val_outputs1_acc: 0.5456 - val_outputs2_acc: 0.1996
# Epoch 6/10
# 300/300 [==============================] - 100s 332ms/step - loss: 4.3109 - outputs1_loss: 1.1316 - outputs2_loss: 3.1794 - outputs1_acc: 0.5922 - outputs2_acc: 0.2128 - val_loss: 4.5079 - val_outputs1_loss: 1.2593 - val_outputs2_loss: 3.2487 - val_outputs1_acc: 0.5594 - val_outputs2_acc: 0.1920
# Epoch 7/10
# 300/300 [==============================] - 101s 335ms/step - loss: 4.1788 - outputs1_loss: 1.0956 - outputs2_loss: 3.0831 - outputs1_acc: 0.6051 - outputs2_acc: 0.2308 - val_loss: 4.2923 - val_outputs1_loss: 1.1448 - val_outputs2_loss: 3.1475 - val_outputs1_acc: 0.5924 - val_outputs2_acc: 0.2176
# Epoch 8/10
# 300/300 [==============================] - 99s 332ms/step - loss: 4.1069 - outputs1_loss: 1.0672 - outputs2_loss: 3.0397 - outputs1_acc: 0.6163 - outputs2_acc: 0.2373 - val_loss: 4.4188 - val_outputs1_loss: 1.2193 - val_outputs2_loss: 3.1995 - val_outputs1_acc: 0.5675 - val_outputs2_acc: 0.2040
# Epoch 9/10
# 300/300 [==============================] - 99s 330ms/step - loss: 4.0347 - outputs1_loss: 1.0515 - outputs2_loss: 2.9831 - outputs1_acc: 0.6213 - outputs2_acc: 0.2473 - val_loss: 4.4781 - val_outputs1_loss: 1.2211 - val_outputs2_loss: 3.2569 - val_outputs1_acc: 0.5722 - val_outputs2_acc: 0.2003
# Epoch 10/10
# 300/300 [==============================] - 98s 328ms/step - loss: 3.9737 - outputs1_loss: 1.0418 - outputs2_loss: 2.9319 - outputs1_acc: 0.6249 - outputs2_acc: 0.2569 - val_loss: 4.1104 - val_outputs1_loss: 1.0730 - val_outputs2_loss: 3.0375 - val_outputs1_acc: 0.6132 - val_outputs2_acc: 0.2413

# %% [markdown]
# 위에서 선언한 `plot_history` 함수를 이용하여 학습이 어떻게 되었는지 확인해봅니다.

# %%
plot_history(history)
# Out:
# CIFAR10  최대 도달 성능: 61.32%
# CIFAR100 최대 도달 성능: 24.13%

# %% [markdown]
# 위에서 정의한 모델은 앞의 transfer learning에서 사용한 student model과 같은 크기의 모델입니다. cifar10에서와 cifar100에서의 모델 성능을 확인해보세요. 하나의 모델만 사용했음에도, 두가지 테스크에서 어느정도 성능을 보여줍니다.

# %% [markdown]
# ## Q2. BN layers를 분리하기 (40 min)
#
# 아래의 두 함수를 수정하여, BN layer가 각 task별로 따로 사용될 수 있도록 분리해보세요.

# %%
def build_shared_conv_block(inputs1, inputs2, num_channels):
    # define layers
    conv = Conv2D(num_channels, (3, 3), padding='same')
    bn1 = BatchNormalization()
    bn2 = BatchNormalization()
    relu = Activation('relu')
    
    # compute outputs
    outputs1 = relu(bn1(conv(inputs1)))
    outputs2 = relu(bn2(conv(inputs2)))
    return outputs1, outputs2

# %% [markdown]
# 이전 실습과 위의 코드를 바탕으로, `model`을 다시 build(`build_network` 이용)하고, compile한 뒤, 학습을 다시 해보세요

# %%
# Q2. build network

def build_network(inputs1, inputs2, num_classes1=10, num_classes2=100, base_width=16):
    x1, x2 = build_shared_conv_block(inputs1, inputs2, base_width)
    x1, x2 = build_shared_conv_block(x1, x2, base_width)
    
    pool1 = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same')
    x1, x2 = pool1(x1), pool1(x2)
    x1, x2 = build_shared_conv_block(x1, x2, base_width*2)
    x1, x2 = build_shared_conv_block(x1, x2, base_width*2)

    pool2 = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same')
    x1, x2 = pool2(x1), pool2(x2)
    x1, x2 = build_shared_conv_block(x1, x2, base_width*4)
    x1, x2 = build_shared_conv_block(x1, x2, base_width*4)

    pool3 = GlobalAveragePooling2D()
    x1, x2 = pool3(x1), pool3(x2)
    
    '''
    logits = GlobalAveragePooling2D()(x3)
    logits = Dense(num_classes)(logits)
    outputs = Activation('softmax')(logits)
    '''
    
    # Q1. Separated Dense layers
    logits1 = Dense(num_classes1)(x1)
    logits2 = Dense(num_classes2)(x2)
    
    outputs1 = Activation('softmax', name='outputs1')(logits1)
    outputs2 = Activation('softmax', name='outputs2')(logits2)
    
    return outputs1, outputs2

inputs1 = Input(shape=(32, 32, 3), name='inputs1')
inputs2 = Input(shape=(32, 32, 3), name='inputs2')

outputs1, outputs2 = build_network(inputs1, inputs2, base_width=8)
model = tf.keras.models.Model(inputs=[inputs1, inputs2], outputs=[outputs1, outputs2], name='model')
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# inputs1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# inputs2 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 8)    224         inputs1[0][0]
#                                                                  inputs2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 8)    32          conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 8)    32          conv2d_6[1][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 8)    0           batch_normalization_6[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 8)    584         activation_6[0][0]
#                                                                  activation_6[1][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 32, 8)    32          conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32, 32, 8)    32          conv2d_7[1][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 8)    0           batch_normalization_8[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 8)    0           activation_7[0][0]
#                                                                  activation_7[1][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 16)   1168        max_pooling2d_2[0][0]
#                                                                  max_pooling2d_2[1][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 16)   64          conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 16)   64          conv2d_8[1][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 16)   0           batch_normalization_10[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 16)   2320        activation_8[0][0]
#                                                                  activation_8[1][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 16)   64          conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 16)   64          conv2d_9[1][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 16)   0           batch_normalization_12[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 16)     0           activation_9[0][0]
#                                                                  activation_9[1][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 32)     4640        max_pooling2d_3[0][0]
#                                                                  max_pooling2d_3[1][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 8, 8, 32)     128         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 8, 8, 32)     128         conv2d_10[1][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 8, 8, 32)     0           batch_normalization_14[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 32)     9248        activation_10[0][0]
#                                                                  activation_10[1][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 8, 8, 32)     128         conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 8, 8, 32)     128         conv2d_11[1][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 8, 8, 32)     0           batch_normalization_16[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 32)           0           activation_11[0][0]
#                                                                  activation_11[1][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 10)           330         global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 100)          3300        global_average_pooling2d_1[1][0]
# __________________________________________________________________________________________________
# outputs1 (Activation)           (None, 10)           0           dense_2[0][0]
# __________________________________________________________________________________________________
# outputs2 (Activation)           (None, 100)          0           dense_3[0][0]
# ==================================================================================================
# Total params: 22,710
# Trainable params: 22,262
# Non-trainable params: 448
# __________________________________________________________________________________________________

# %%
# Q2: model compile
model.compile(optimizer='adam',
              loss=['categorical_crossentropy', 'categorical_crossentropy'], # output이 2개이기 때문에 각각에 대해 loss를 지정해주어야 합니다.
              metrics=['accuracy', 'accuracy']) # output이 2개이기 때문에 각각에 대해 metric을 지정해주어야 합니다.

# %%
# Q2: train model & training curve visualization
history = model.fit_generator(datagen,
                              steps_per_epoch=steps_per_epoch,
                              epochs=num_epochs,
                              validation_data=test_datagen,
                              validation_steps=100, verbose=1)
   
plot_history(history)
# Out:
# Epoch 1/10
# 300/300 [==============================] - 101s 337ms/step - loss: 6.0466 - outputs1_loss: 1.7217 - outputs2_loss: 4.3249 - outputs1_acc: 0.3896 - outputs2_acc: 0.0522 - val_loss: 7.1180 - val_outputs1_loss: 2.7145 - val_outputs2_loss: 4.4035 - val_outputs1_acc: 0.2126 - val_outputs2_acc: 0.0380
# Epoch 2/10
# 300/300 [==============================] - 99s 332ms/step - loss: 5.2727 - outputs1_loss: 1.4218 - outputs2_loss: 3.8509 - outputs1_acc: 0.4851 - outputs2_acc: 0.1093 - val_loss: 5.2765 - val_outputs1_loss: 1.5035 - val_outputs2_loss: 3.7730 - val_outputs1_acc: 0.4391 - val_outputs2_acc: 0.1066
# Epoch 3/10
# 300/300 [==============================] - 99s 329ms/step - loss: 4.8974 - outputs1_loss: 1.3030 - outputs2_loss: 3.5944 - outputs1_acc: 0.5308 - outputs2_acc: 0.1417 - val_loss: 4.8692 - val_outputs1_loss: 1.3415 - val_outputs2_loss: 3.5277 - val_outputs1_acc: 0.5193 - val_outputs2_acc: 0.1474
# Epoch 4/10
# 300/300 [==============================] - 102s 340ms/step - loss: 4.6106 - outputs1_loss: 1.2124 - outputs2_loss: 3.3982 - outputs1_acc: 0.5667 - outputs2_acc: 0.1757 - val_loss: 4.6840 - val_outputs1_loss: 1.2871 - val_outputs2_loss: 3.3969 - val_outputs1_acc: 0.5369 - val_outputs2_acc: 0.1686
# Epoch 5/10
# 300/300 [==============================] - 99s 331ms/step - loss: 4.4416 - outputs1_loss: 1.1708 - outputs2_loss: 3.2708 - outputs1_acc: 0.5818 - outputs2_acc: 0.1958 - val_loss: 4.4246 - val_outputs1_loss: 1.1712 - val_outputs2_loss: 3.2535 - val_outputs1_acc: 0.5816 - val_outputs2_acc: 0.1873
# Epoch 6/10
# 300/300 [==============================] - 99s 330ms/step - loss: 4.2886 - outputs1_loss: 1.1199 - outputs2_loss: 3.1687 - outputs1_acc: 0.6000 - outputs2_acc: 0.2134 - val_loss: 4.3961 - val_outputs1_loss: 1.1470 - val_outputs2_loss: 3.2492 - val_outputs1_acc: 0.5868 - val_outputs2_acc: 0.1929
# Epoch 7/10
# 300/300 [==============================] - 107s 356ms/step - loss: 4.1872 - outputs1_loss: 1.0936 - outputs2_loss: 3.0936 - outputs1_acc: 0.6099 - outputs2_acc: 0.2274 - val_loss: 4.4247 - val_outputs1_loss: 1.2029 - val_outputs2_loss: 3.2218 - val_outputs1_acc: 0.5783 - val_outputs2_acc: 0.1980
# Epoch 8/10
# 300/300 [==============================] - 106s 352ms/step - loss: 4.0809 - outputs1_loss: 1.0536 - outputs2_loss: 3.0273 - outputs1_acc: 0.6261 - outputs2_acc: 0.2385 - val_loss: 4.5053 - val_outputs1_loss: 1.2002 - val_outputs2_loss: 3.3051 - val_outputs1_acc: 0.5730 - val_outputs2_acc: 0.1914
# Epoch 9/10
# 300/300 [==============================] - 102s 341ms/step - loss: 4.0122 - outputs1_loss: 1.0401 - outputs2_loss: 2.9720 - outputs1_acc: 0.6290 - outputs2_acc: 0.2503 - val_loss: 4.2078 - val_outputs1_loss: 1.1019 - val_outputs2_loss: 3.1059 - val_outputs1_acc: 0.6111 - val_outputs2_acc: 0.2219
# Epoch 10/10
# 300/300 [==============================] - 103s 342ms/step - loss: 3.9381 - outputs1_loss: 1.0272 - outputs2_loss: 2.9109 - outputs1_acc: 0.6358 - outputs2_acc: 0.2612 - val_loss: 4.2915 - val_outputs1_loss: 1.1989 - val_outputs2_loss: 3.0926 - val_outputs1_acc: 0.5740 - val_outputs2_acc: 0.2216
# CIFAR10  최대 도달 성능: 61.11%
# CIFAR100 최대 도달 성능: 22.19%

# %% [markdown]
# ## Assignment 2: 최적의 구조 찾기
#
# - 앞 실습에서는 마지막 output layer와 BN layer를 각 task별로 분리하고, 나머지 convolutional layer는 task에 상관없이 공유하도록 디자인하였습니다.
# - 하지만 task에 따라서 일부 convolutional layer를 분리시키는게 나을 수도 있습니다. 예를 들어, low-level convolutional layer는 공유하지만, high-level convolutional layer는 공유하지 않도록 할 수도 있습니다.
# - 이번 실습에서는 다양한 형태로 모델을 분리/공유시켜보면서 성능이 어떻게 변하는지 확인해보세요. 좋은 구조를 찾은 분께는 가산점을 드릴 예정입니다.
# - **제출은 README.md 파일을 참고하세요.**

# %%
def build_shared_conv_block_together(inputs1, inputs2, num_channels):
    # define layers
    conv = Conv2D(num_channels, (3, 3), padding='same')
    bn = BatchNormalization()
    relu = Activation('relu')
    
    # compute outputs
    outputs1 = relu(bn(conv(inputs1)))
    outputs2 = relu(bn(conv(inputs2)))
    return outputs1, outputs2

def build_shared_conv_block_divide(inputs1, inputs2, num_channels):
    # A2. 자신만의 공유/분리 구조를 만들어보세요
    # define layers
    conv = Conv2D(num_channels, (3, 3), padding='same')
    bn1 = BatchNormalization()
    bn2 = BatchNormalization()
    relu = Activation('relu')
    
    # compute outputs
    outputs1 = relu(bn1(conv(inputs1)))
    outputs2 = relu(bn2(conv(inputs2)))
    return outputs1, outputs2

# %%
def build_network(inputs1, inputs2, num_classes1=10, num_classes2=100, base_width=16):
    # A2. 자신만의 공유/분리 구조를 만들어보세요
    #x1, x2 = build_shared_conv_block(inputs1, inputs2, base_width)
    #x1, x2 = build_shared_conv_block(x1, x2, base_width)
    x1, x2 = build_shared_conv_block_together(inputs1, inputs2, base_width)
    x1, x2 = build_shared_conv_block_together(x1, x2, base_width)
    
    pool1 = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same')
    x1, x2 = pool1(x1), pool1(x2)
    #x1, x2 = build_shared_conv_block(x1, x2, base_width*2)
    #x1, x2 = build_shared_conv_block(x1, x2, base_width*2)
    #x1, x2 = build_shared_conv_block_divide(x1, x2, base_width*2)
    #x1, x2 = build_shared_conv_block_divide(x1, x2, base_width*2)
    x1, x2 = build_shared_conv_block_together(x1, x2, base_width*2)
    x1, x2 = build_shared_conv_block_together(x1, x2, base_width*2)

    pool2 = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same')
    x1, x2 = pool2(x1), pool2(x2)
    #x1, x2 = build_shared_conv_block_divide(x1, x2, base_width*4)
    #x1, x2 = build_shared_conv_block_divide(x1, x2, base_width*4)
    x1, x2 = build_shared_conv_block_divide(x1, x2, base_width*4)
    x1, x2 = build_shared_conv_block_divide(x1, x2, base_width*4)

    pool3 = GlobalAveragePooling2D()
    x1, x2 = pool3(x1), pool3(x2)
    
    # Q1. Separated Dense layers
    logits1 = Dense(num_classes1)(x1)
    logits2 = Dense(num_classes2)(x2)
    
    outputs1 = Activation('softmax', name='outputs1')(logits1)
    outputs2 = Activation('softmax', name='outputs2')(logits2)
    
    return outputs1, outputs2


inputs1 = Input(shape=(32, 32, 3), name='inputs1')
inputs2 = Input(shape=(32, 32, 3), name='inputs2')

# %%
# A2. build network
outputs1, outputs2 = build_network(inputs1, inputs2, base_width=8)
model = tf.keras.models.Model(inputs=[inputs1, inputs2], outputs=[outputs1, outputs2], name='model')
model.summary()

# A2. model compile
model.compile(optimizer='adam',
              loss=['categorical_crossentropy', 'categorical_crossentropy'], # output이 2개이기 때문에 각각에 대해 loss를 지정해주어야 합니다.
              metrics=['accuracy', 'accuracy']) # output이 2개이기 때문에 각각에 대해 metric을 지정해주어야 합니다.
# A2. model train
history = model.fit_generator(datagen,
                              steps_per_epoch=steps_per_epoch,
                              epochs=num_epochs,
                              validation_data=test_datagen,
                              validation_steps=100, verbose=1)
# A2. training curve visualization
history = model.fit_generator(datagen,
                              steps_per_epoch=steps_per_epoch,
                              epochs=num_epochs,
                              validation_data=test_datagen,
                              validation_steps=100, verbose=1)
plot_history(history)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# inputs1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# inputs2 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 32, 32, 8)    224         inputs1[0][0]
#                                                                  inputs2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 32, 32, 8)    32          conv2d_18[0][0]
#                                                                  conv2d_18[1][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 32, 32, 8)    0           batch_normalization_28[0][0]
#                                                                  batch_normalization_28[1][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 32, 32, 8)    584         activation_18[0][0]
#                                                                  activation_18[1][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 32, 32, 8)    32          conv2d_19[0][0]
#                                                                  conv2d_19[1][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 32, 32, 8)    0           batch_normalization_29[0][0]
#                                                                  batch_normalization_29[1][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 16, 16, 8)    0           activation_19[0][0]
#                                                                  activation_19[1][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 16, 16, 16)   1168        max_pooling2d_6[0][0]
#                                                                  max_pooling2d_6[1][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 16, 16, 16)   64          conv2d_20[0][0]
#                                                                  conv2d_20[1][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 16, 16, 16)   0           batch_normalization_30[0][0]
#                                                                  batch_normalization_30[1][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 16, 16, 16)   2320        activation_20[0][0]
#                                                                  activation_20[1][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 16, 16, 16)   64          conv2d_21[0][0]
#                                                                  conv2d_21[1][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 16, 16, 16)   0           batch_normalization_31[0][0]
#                                                                  batch_normalization_31[1][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 8, 8, 16)     0           activation_21[0][0]
#                                                                  activation_21[1][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 8, 8, 32)     4640        max_pooling2d_7[0][0]
#                                                                  max_pooling2d_7[1][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 8, 8, 32)     128         conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 8, 8, 32)     128         conv2d_22[1][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 8, 8, 32)     0           batch_normalization_32[0][0]
#                                                                  batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 8, 8, 32)     9248        activation_22[0][0]
#                                                                  activation_22[1][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 8, 8, 32)     128         conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 8, 8, 32)     128         conv2d_23[1][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 8, 8, 32)     0           batch_normalization_34[0][0]
#                                                                  batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 32)           0           activation_23[0][0]
#                                                                  activation_23[1][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 10)           330         global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 100)          3300        global_average_pooling2d_3[1][0]
# __________________________________________________________________________________________________
# outputs1 (Activation)           (None, 10)           0           dense_6[0][0]
# __________________________________________________________________________________________________
# outputs2 (Activation)           (None, 100)          0           dense_7[0][0]
# ==================================================================================================
# Total params: 22,518
# Trainable params: 22,166
# Non-trainable params: 352
# __________________________________________________________________________________________________
# Epoch 1/10
# 300/300 [==============================] - 104s 345ms/step - loss: 6.0626 - outputs1_loss: 1.7173 - outputs2_loss: 4.3453 - outputs1_acc: 0.3720 - outputs2_acc: 0.0504 - val_loss: 5.6432 - val_outputs1_loss: 1.5876 - val_outputs2_loss: 4.0556 - val_outputs1_acc: 0.4011 - val_outputs2_acc: 0.0757
# Epoch 2/10
# 300/300 [==============================] - 100s 333ms/step - loss: 5.2794 - outputs1_loss: 1.4227 - outputs2_loss: 3.8567 - outputs1_acc: 0.4807 - outputs2_acc: 0.1099 - val_loss: 5.2487 - val_outputs1_loss: 1.5281 - val_outputs2_loss: 3.7206 - val_outputs1_acc: 0.4428 - val_outputs2_acc: 0.1197
# Epoch 3/10
# 300/300 [==============================] - 99s 330ms/step - loss: 4.8824 - outputs1_loss: 1.2937 - outputs2_loss: 3.5887 - outputs1_acc: 0.5289 - outputs2_acc: 0.1447 - val_loss: 4.7794 - val_outputs1_loss: 1.3048 - val_outputs2_loss: 3.4745 - val_outputs1_acc: 0.5288 - val_outputs2_acc: 0.1554
# Epoch 4/10
# 300/300 [==============================] - 99s 331ms/step - loss: 4.6292 - outputs1_loss: 1.2230 - outputs2_loss: 3.4062 - outputs1_acc: 0.5550 - outputs2_acc: 0.1731 - val_loss: 4.7210 - val_outputs1_loss: 1.3152 - val_outputs2_loss: 3.4057 - val_outputs1_acc: 0.5240 - val_outputs2_acc: 0.1636
# Epoch 5/10
# 300/300 [==============================] - 99s 331ms/step - loss: 4.4507 - outputs1_loss: 1.1639 - outputs2_loss: 3.2868 - outputs1_acc: 0.5777 - outputs2_acc: 0.1962 - val_loss: 4.7177 - val_outputs1_loss: 1.3107 - val_outputs2_loss: 3.4069 - val_outputs1_acc: 0.5303 - val_outputs2_acc: 0.1717
# Epoch 6/10
# 300/300 [==============================] - 101s 336ms/step - loss: 4.3077 - outputs1_loss: 1.1268 - outputs2_loss: 3.1809 - outputs1_acc: 0.5934 - outputs2_acc: 0.2155 - val_loss: 4.3979 - val_outputs1_loss: 1.1528 - val_outputs2_loss: 3.2451 - val_outputs1_acc: 0.5855 - val_outputs2_acc: 0.1962
# Epoch 7/10
# 300/300 [==============================] - 104s 348ms/step - loss: 4.2039 - outputs1_loss: 1.0916 - outputs2_loss: 3.1123 - outputs1_acc: 0.6055 - outputs2_acc: 0.2247 - val_loss: 4.5533 - val_outputs1_loss: 1.2511 - val_outputs2_loss: 3.3022 - val_outputs1_acc: 0.5536 - val_outputs2_acc: 0.1888
# Epoch 8/10
# 300/300 [==============================] - 101s 338ms/step - loss: 4.1175 - outputs1_loss: 1.0775 - outputs2_loss: 3.0399 - outputs1_acc: 0.6100 - outputs2_acc: 0.2379 - val_loss: 4.8102 - val_outputs1_loss: 1.5020 - val_outputs2_loss: 3.3082 - val_outputs1_acc: 0.4922 - val_outputs2_acc: 0.1957
# Epoch 9/10
# 300/300 [==============================] - 102s 339ms/step - loss: 4.0298 - outputs1_loss: 1.0615 - outputs2_loss: 2.9682 - outputs1_acc: 0.6174 - outputs2_acc: 0.2492 - val_loss: 4.3691 - val_outputs1_loss: 1.2438 - val_outputs2_loss: 3.1253 - val_outputs1_acc: 0.5718 - val_outputs2_acc: 0.2220
# Epoch 10/10
# 300/300 [==============================] - 101s 337ms/step - loss: 3.9701 - outputs1_loss: 1.0420 - outputs2_loss: 2.9281 - outputs1_acc: 0.6235 - outputs2_acc: 0.2609 - val_loss: 4.7106 - val_outputs1_loss: 1.2853 - val_outputs2_loss: 3.4253 - val_outputs1_acc: 0.5398 - val_outputs2_acc: 0.1799
# Epoch 1/10
# 300/300 [==============================] - 100s 333ms/step - loss: 3.9161 - outputs1_loss: 1.0222 - outputs2_loss: 2.8939 - outputs1_acc: 0.6315 - outputs2_acc: 0.2638 - val_loss: 4.1757 - val_outputs1_loss: 1.0868 - val_outputs2_loss: 3.0888 - val_outputs1_acc: 0.6185 - val_outputs2_acc: 0.2283
# Epoch 2/10
# 300/300 [==============================] - 100s 334ms/step - loss: 3.8736 - outputs1_loss: 1.0137 - outputs2_loss: 2.8599 - outputs1_acc: 0.6349 - outputs2_acc: 0.2757 - val_loss: 4.4007 - val_outputs1_loss: 1.1071 - val_outputs2_loss: 3.2936 - val_outputs1_acc: 0.6090 - val_outputs2_acc: 0.2049
# Epoch 3/10
# 300/300 [==============================] - 101s 335ms/step - loss: 3.8343 - outputs1_loss: 1.0065 - outputs2_loss: 2.8278 - outputs1_acc: 0.6362 - outputs2_acc: 0.2800 - val_loss: 4.1760 - val_outputs1_loss: 1.1176 - val_outputs2_loss: 3.0584 - val_outputs1_acc: 0.6089 - val_outputs2_acc: 0.2418
# Epoch 4/10
# 300/300 [==============================] - 102s 339ms/step - loss: 3.7860 - outputs1_loss: 0.9949 - outputs2_loss: 2.7912 - outputs1_acc: 0.6451 - outputs2_acc: 0.2867 - val_loss: 3.9684 - val_outputs1_loss: 1.1142 - val_outputs2_loss: 2.8543 - val_outputs1_acc: 0.6089 - val_outputs2_acc: 0.2702
# Epoch 5/10
# 300/300 [==============================] - 100s 334ms/step - loss: 3.7548 - outputs1_loss: 0.9843 - outputs2_loss: 2.7705 - outputs1_acc: 0.6453 - outputs2_acc: 0.2875 - val_loss: 4.1698 - val_outputs1_loss: 1.0615 - val_outputs2_loss: 3.1083 - val_outputs1_acc: 0.6196 - val_outputs2_acc: 0.2368
# Epoch 6/10
# 300/300 [==============================] - 101s 335ms/step - loss: 3.7255 - outputs1_loss: 0.9796 - outputs2_loss: 2.7459 - outputs1_acc: 0.6480 - outputs2_acc: 0.2939 - val_loss: 3.8123 - val_outputs1_loss: 1.0166 - val_outputs2_loss: 2.7957 - val_outputs1_acc: 0.6462 - val_outputs2_acc: 0.2803
# Epoch 7/10
# 300/300 [==============================] - 102s 339ms/step - loss: 3.6993 - outputs1_loss: 0.9712 - outputs2_loss: 2.7281 - outputs1_acc: 0.6549 - outputs2_acc: 0.3008 - val_loss: 4.0623 - val_outputs1_loss: 1.1296 - val_outputs2_loss: 2.9327 - val_outputs1_acc: 0.6095 - val_outputs2_acc: 0.2632
# Epoch 8/10
# 300/300 [==============================] - 102s 341ms/step - loss: 3.6617 - outputs1_loss: 0.9650 - outputs2_loss: 2.6967 - outputs1_acc: 0.6570 - outputs2_acc: 0.3045 - val_loss: 4.0829 - val_outputs1_loss: 1.0950 - val_outputs2_loss: 2.9879 - val_outputs1_acc: 0.6207 - val_outputs2_acc: 0.2535
# Epoch 9/10
# 300/300 [==============================] - 101s 335ms/step - loss: 3.6330 - outputs1_loss: 0.9487 - outputs2_loss: 2.6843 - outputs1_acc: 0.6607 - outputs2_acc: 0.3073 - val_loss: 4.0011 - val_outputs1_loss: 1.0357 - val_outputs2_loss: 2.9655 - val_outputs1_acc: 0.6371 - val_outputs2_acc: 0.2604
# Epoch 10/10
# 300/300 [==============================] - 100s 333ms/step - loss: 3.6152 - outputs1_loss: 0.9494 - outputs2_loss: 2.6658 - outputs1_acc: 0.6577 - outputs2_acc: 0.3110 - val_loss: 4.0942 - val_outputs1_loss: 1.2095 - val_outputs2_loss: 2.8847 - val_outputs1_acc: 0.6047 - val_outputs2_acc: 0.2844
# CIFAR10  최대 도달 성능: 64.62%
# CIFAR100 최대 도달 성능: 28.44%
